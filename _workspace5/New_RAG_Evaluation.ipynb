# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, accuracy_score
import seaborn as sns

plt.rc('font', family='AppleGothic')

# %%
# file_path = './Data/CorrectAnswer/'
# file_name = 'CorrectAnswer_Dataset_Ver1.0'

# ### Exaone
# exaone_name_list = ['New_RAG_EXAONE_3.5_2.4b_3352',
#                     'New_RAG_EXAONE-4.0-1.2B-GGUF_IQ4_XS',
#                     'New_RAG_EXAONE-4.0-1.2B-GGUF_BF16',
#                     'New_RAG_EXAONE-Deep-2.4B-GGUF_Q4_K_M',
#                     'New_RAG_EXAONE-Deep-2.4B-GGUF_Q4_BF16',
#                     'New_RAG_EXAONE-Deep-7.8B-GGUF_Q4_K_M'
#                    ]
# ### Deepseek
# deepseek_name_list = ['New_RAG_Deepseek_r1_1.5b']

# ### Gemma
# gemma_name_list = ['New_RAG_gemma3_1b',
#                    'New_RAG_gemma3_4b']

# ### Llama
# llama_name_list = ['New_RAG_llama-3.2-Korean-Bllossom-3B-gguf-Q4_K_M',
#                   'New_RAG_llama-3.2-Korean-Bllossom-3B-GGUF_Q2_K']

# %%
file_path = './Data/CorrectAnswer/'
file_name = 'CorrectAnswer_Dataset_Ver1.0'

### Exaone
exaone_name_list = ['New_RAG_EXAONE-Deep-2.4B-GGUF_Q4_K_M_0.3',
                    'New_RAG_EXAONE-4.0-1.2B-GGUF_IQ4_XS_0.3',
                    'New_RAG_EXAONE-Deep-7.8B-GGUF_Q4_K_M_0.3',
                    'New_RAG_llama-3.2-Korean-Bllossom-3B-GGUF_Q2_K_0.3'
                   ]
### Deepseek
deepseek_name_list = []

### Gemma
gemma_name_list = ['New_RAG_gemma3_1b_0.3']

### Llama
llama_name_list = []

# %% [markdown]
# # 성능비교

# %%
# 정답 데이터셋
df_ca = pd.read_csv(file_path+file_name+'.csv')

# 정제 데이터셋
## FewShot Dataset - Exaone
df_fs_exaone = pd.read_csv(file_path+'Fewshot_Exaone_3.5_2.4b_3352'+'.csv')

## RAG Model Dataset

# df_rag_exaone = [pd.read_csv(os.path.join(file_path,f'{lst}.csv')) for lst in exaone_name_list]
df_rag_exaone = [pd.read_csv(file_path+f'{lst}.csv') for lst in exaone_name_list]

### Deepseek
df_rag_deepseek = [pd.read_csv(file_path+f'{lst}.csv') for lst in deepseek_name_list]

### Gemma
df_rag_gemma = [pd.read_csv(file_path+f'{lst}.csv') for lst in gemma_name_list]

### Llama
df_rag_llama = [pd.read_csv(file_path+f'{lst}.csv') for lst in llama_name_list]

# %%
df_ca
# Out:
#      Original_Name Correct_Name Brand Power_Source Specification  \
# 0         180mm 샌더           샌더   NaN          NaN         180mm
# 1          LED 손전등          손전등   NaN          NaN           LED
# 2        경랑몽키(8인치)        몽키스패너   NaN          NaN        경량 8인치
# 3            고압세척기        고압세척기   NaN          NaN           NaN
# 4          바이스플라이어      바이스플라이어   NaN          NaN           NaN
# ...            ...          ...   ...          ...           ...
# 3347       휴대용에어펌프         에어펌프   NaN           무선           NaN
# 3348        휴대용유모차          유모차   NaN          NaN           NaN
# 3349       휴대용육각렌치         육각렌치   NaN          NaN           접이식
# 3350            흙손          미장칼   NaN          NaN           NaN
# 3351       힐티기리6mm         드릴비트    힐티          NaN           6mm
#
#      SubCategories Categories Dirtydata_Category Dirtydata_Subtype  \
# 0            샌더/대패       전동공구              정보중복형              속성기입
# 1          기타 일반공구       일반공구              정보중복형             동력원명시
# 2        몽키/렌치/스패너       일반공구              표준위배형               오탈자
# 3             기타공구       기타공구              정보중복형             동력원명시
# 4       니퍼/펜치/플라이어       일반공구                NaN               NaN
# ...            ...        ...                ...               ...
# 3347       기타 생활용품       생활용품              정보중복형             동력원명시
# 3348       기타 생활용품       생활용품                NaN               NaN
# 3349     몽키/렌치/스패너       일반공구                NaN               NaN
# 3350        도장/페인트       일반공구                NaN               NaN
# 3351            비트       전동공구              정보중복형             브랜드혼입
#
#                                             근거 (보고서 패턴)
# 0                      규격('180mm')이 Original_Name에 포함됨.
# 1     손전등'은 암묵적으로 동력원(충전)을 가짐에도 이름에 동력원이 없음이 플래그됨 (암...
# 2                                       경랑'은 '경량'의 오탈자.
# 3     동력원 언급이 없지만 Power_Source가 올바르게 분류됨 (암묵적 규칙 충돌의...
# 4            분류표에 명시된 더티 데이터 유형에 해당하지 않는 깨끗한 제품명으로 판단됨.
# ...                                                 ...
# 3347                                       동력원 '에어' 포함.
# 3348                                            공구가 아님.
# 3349                            명확한 더티 데이터 유형에 해당하지 않음.
# 3350                            명확한 더티 데이터 유형에 해당하지 않음.
# 3351                                       브랜드 '힐티' 포함.
#
# [3352 rows x 10 columns]

# %%
all_name_lists = [exaone_name_list, deepseek_name_list, gemma_name_list, llama_name_list]
all_df_lists = [df_rag_exaone, df_rag_deepseek, df_rag_gemma, df_rag_llama]

# %%
df_eval = df_ca[['Correct_Name']].copy()
df_eval['FewShot_Exaone_3.5_2.4b'] = df_fs_exaone['Preprocessed_Name']
df_eval
# Out:
#      Correct_Name FewShot_Exaone_3.5_2.4b
# 0              샌더                      샌더
# 1             손전등                     손전등
# 2           몽키스패너                   몽키스패너
# 3           고압세척기                     세척기
# 4         바이스플라이어                 바이스플라이어
# ...           ...                     ...
# 3347         에어펌프                    에어펌프
# 3348          유모차                     유모차
# 3349         육각렌치                    육각렌치
# 3350          미장칼                      흙손
# 3351         드릴비트                    드릴비트
#
# [3352 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split
df_train, df_eval = train_test_split(df_eval, test_size=0.3, random_state=42)

# %%
df_eval = df_eval.reset_index(drop = True)

# %%
### 정답지, 정제된 데이터로 평가할 데이터셋 만들기 
# df_eval['FewShot_Exaone3.5:2.4b'] = df_fs_exaone1['Preprocessed_Name']
# df_eval['RAG_Exaone3.5:2.4b'] = df_rag_exaone1['Preprocessed_Name']
# df_eval['RAG_Exaone4.0:1.2b'] = df_rag_exaone2['Preprocessed_Name']
# df_eval['RAG_Gemma3_4'] = df_rag_gemma1['Preprocessed_Name']
# df_eval['RAG_Deepseek_r1:1.5b'] = df_rag_deepseek1['Preprocessed_Name']
# df_eval['Llama-3.2-Korean-Bllossom-3B'] = df_rag_llama1['Preprocessed_Name']

for df_list, name_list in zip(all_df_lists, all_name_lists):
    for i, df in enumerate(df_list):
        new_col_name = name_list[i]
        df_eval[new_col_name] = df['Preprocessed_Name']

# 결측치 처리
df_eval = df_eval.fillna('NaN').copy().reset_index(drop = True)
df_eval
# Out:
#      Correct_Name FewShot_Exaone_3.5_2.4b  \
# 0               톱                       톱
# 1             방역기                     방역기
# 2             전선릴                     차단릴
# 3           몽키스패너                    몽키드릴
# 4               톱                       톱
# ...           ...                     ...
# 1001        몽키스패너                   몽키스패너
# 1002           렌치                      렌치
# 1003         드라이버                    드라이버
# 1004         그라인더                    그라인더
# 1005        파이프렌치                   파이프렌치
#
#      New_RAG_EXAONE-Deep-2.4B-GGUF_Q4_K_M_0.3  \
# 0                                           톱
# 1                                         방정기
# 2                                         전선릴
# 3                                       몽키스패너
# 4                                           톱
# ...                                       ...
# 1001                                    몽키스패너
# 1002                                       렌치
# 1003                                    대드라이버
# 1004                                     그라인더
# 1005                                    파이프렌치
#
#      New_RAG_EXAONE-4.0-1.2B-GGUF_IQ4_XS_0.3  \
# 0                                          톱
# 1                                        방역기
# 2                                        전선릴
# 3                                      몽키스패너
# 4                                          톱
# ...                                      ...
# 1001                                   몽키스패너
# 1002                                      렌치
# 1003                                   대드라이버
# 1004                                  핸드그라인더
# 1005                                   파이프렌치
#
#      New_RAG_EXAONE-Deep-7.8B-GGUF_Q4_K_M_0.3  \
# 0                                           톱
# 1                                         방역기
# 2                                           릴
# 3                                       몽키스패너
# 4                                           톱
# ...                                       ...
# 1001                                    몽키스패너
# 1002                                       렌치
# 1003                                    대드라이버
# 1004                                     그라인더
# 1005                                    파이프렌치
#
#      New_RAG_llama-3.2-Korean-Bllossom-3B-GGUF_Q2_K_0.3 New_RAG_gemma3_1b_0.3
# 0                                                  톱(대)                     톱
# 1                                                   방역기                   방역기
# 2                                                   전선릴                   전선릴
# 3                                                 몽키스패너                 몽키스패너
# 4                                                   소형톱                     톱
# ...                                                 ...                   ...
# 1001                                           몽키스패너(2)                   스패너
# 1002                                                レン치                    렌치
# 1003                                              대드라이버                  드라이버
# 1004                                               그라인더                  그라인더
# 1005                                          파이프렌치(12)                 파이프렌치
#
# [1006 rows x 7 columns]

# %%
# --- LabelEncoder 준비 ---
# TypeError(float) 및 ValueError(mismatch) 방지를 위해
# .astype(str) 및 labels= 파라미터 사용
col_name_list = df_eval.columns.tolist()

# 1. 4개 리스트의 모든 고유값을 .astype(str)로 합칩니다.
# (결측치(None)나 오류가 있어도 str로 변환되어 처리됨)

## 모든 라벨에 대해서 
# all_labels = pd.concat([df_eval.iloc[:,1:].stack().astype(str)]).unique()
all_labels = pd.concat([df_eval[col].astype(str) for col in col_name_list]).unique()
all_labels
# Out:
# array(['톱', '방역기', '전선릴', ..., '파솔세트', '워킹', '육각볼렌치센트'], dtype=object)

# %%
# 2. LabelEncoder를 모든 레이블에 맞게 학습시킵니다.
le = LabelEncoder()
le.fit(all_labels)
# Out:
# LabelEncoder()

# %%
le.classes_
# Out:
# array([' drills', '(14)커터칼', '(19)소CKETレン치세트', ..., '히팅건', '힐티기리',
#        '힐티기리6mm'], dtype=object)

# %%
col_name_list = df_eval.columns.tolist()

# %%
col_name_list
# Out:
# ['Correct_Name',
#  'FewShot_Exaone_3.5_2.4b',
#  'New_RAG_EXAONE-Deep-2.4B-GGUF_Q4_K_M_0.3',
#  'New_RAG_EXAONE-4.0-1.2B-GGUF_IQ4_XS_0.3',
#  'New_RAG_EXAONE-Deep-7.8B-GGUF_Q4_K_M_0.3',
#  'New_RAG_llama-3.2-Korean-Bllossom-3B-GGUF_Q2_K_0.3',
#  'New_RAG_gemma3_1b_0.3']

# %%
# 모든 레이블의 인코딩된 리스트를 가져옵니다. (labels= 파라미터용)
all_encoded_labels = le.transform(le.classes_)
y_true_enc = le.transform(df_eval[col_name_list[0]].astype(str))
# 2. 나머지 예측 레이블(y_pred)들을 리스트 컴프리헨션으로 한 번에 인코딩하고 리스트에 저장
y_preds_enc_list = [
    le.transform(df_eval.loc[:, col_name].astype(str))
    for col_name in col_name_list[1:] ]

# %%
print("--- [평가 1] 데이터 품질 평가 리포트 ---\n")
# --- 리포트 생성 ---

report_data = zip(y_preds_enc_list, col_name_list[1:])
report_list = []

for y_pred_enc, col_name in report_data:
    # classification_report 출력
    report_list.append(classification_report(y_true_enc,
                                y_pred_enc,
                                target_names=le.classes_,
                                zero_division=0,
                                labels=all_encoded_labels))
    print(f" To-Be (LLM / {col_name}) 성능 평가 리포트 저장 완료")
# Out:
# --- [평가 1] 데이터 품질 평가 리포트 ---
#
#  To-Be (LLM / FewShot_Exaone_3.5_2.4b) 성능 평가 리포트 저장 완료
#  To-Be (LLM / New_RAG_EXAONE-Deep-2.4B-GGUF_Q4_K_M_0.3) 성능 평가 리포트 저장 완료
#  To-Be (LLM / New_RAG_EXAONE-4.0-1.2B-GGUF_IQ4_XS_0.3) 성능 평가 리포트 저장 완료
#  To-Be (LLM / New_RAG_EXAONE-Deep-7.8B-GGUF_Q4_K_M_0.3) 성능 평가 리포트 저장 완료
#  To-Be (LLM / New_RAG_llama-3.2-Korean-Bllossom-3B-GGUF_Q2_K_0.3) 성능 평가 리포트 저장 완료
#  To-Be (LLM / New_RAG_gemma3_1b_0.3) 성능 평가 리포트 저장 완료

# %%
### 정확도 계산
accuracies = [
    accuracy_score(y_true_enc, y_pred_enc)
    for y_pred_enc in y_preds_enc_list
]

# %%
df_plot = pd.DataFrame({
    'Method': col_name_list[1:],
    'Accuracy': accuracies
})

# %%
# 정확도 순으로 정렬 (가장 낮은 것이 왼쪽으로 오도록 ascending=True)
df_plot = df_plot.sort_values(by='Accuracy', ascending=True)

# %%
df_plot.sort_values(by='Accuracy', ascending=False)
# Out:
#                                               Method  Accuracy
# 5                              New_RAG_gemma3_1b_0.3  0.581511
# 2            New_RAG_EXAONE-4.0-1.2B-GGUF_IQ4_XS_0.3  0.532803
# 3           New_RAG_EXAONE-Deep-7.8B-GGUF_Q4_K_M_0.3  0.523857
# 0                            FewShot_Exaone_3.5_2.4b  0.402584
# 1           New_RAG_EXAONE-Deep-2.4B-GGUF_Q4_K_M_0.3  0.378728
# 4  New_RAG_llama-3.2-Korean-Bllossom-3B-GGUF_Q2_K...  0.253479

# %%
# 4. 막대 그래프 시각화
plt.figure(figsize=(12, 7)) # 가로 폭을 넓혀 폰트 겹침 방지

# hue를 사용하지 않고 barplot 생성 (하나의 카테고리이므로)
barplot = sns.barplot(
    x='Method',
    y='Accuracy',
    data=df_plot,
    palette='viridis'
)
# 그래프에 수치 표시 (소수점 2자리 백분율)
for p in barplot.patches:
    barplot.annotate(f'{p.get_height():.2%}',
                     (p.get_x() + p.get_width() / 2., p.get_height()),
                     ha='center', va='center',
                     xytext=(0, 9),
                     textcoords='offset points',
                     fontsize=12,
                     fontweight='bold')

plt.title('방법론별 공구 이름 정제 정확도 비교', fontsize=16, fontweight='bold')
plt.ylabel('정확도 (Accuracy)', fontsize=14)
plt.xlabel('방법론', fontsize=14)
plt.xticks(rotation=45, ha='right') # 모델 이름이 길 경우 회전하여 겹침 방지
plt.ylim(0, 1.05) 

# 시각화 결과 보여주기
plt.tight_layout() # 그래프 요소가 잘리지 않도록 레이아웃 자동 조정

plt.savefig('./Data/Pigure/LLM_Accuracy/'+'Accuracy_Camprison_x2')
plt.show()
print("\n--- 모든 평가 완료 ---")
# Out:
# /var/folders/sk/2ps_1bcs0l52p501k_6p6h_m0000gn/T/ipykernel_17465/2278079806.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   barplot = sns.barplot(
# --- 모든 평가 완료 ---

# %%
# 4. 막대 그래프 시각화
plt.figure(figsize=(12, 7)) # 가로 폭을 넓혀 폰트 겹침 방지

# hue를 사용하지 않고 barplot 생성 (하나의 카테고리이므로)
barplot = sns.barplot(
    hue='Method',
    y='Accuracy',
    data=df_plot,
    palette='viridis'
)
# 그래프에 수치 표시 (소수점 2자리 백분율)
for p in barplot.patches:
    barplot.annotate(f'{p.get_height():.2%}',
                     (p.get_x() + p.get_width() / 2., p.get_height()),
                     ha='center', va='center',
                     xytext=(0, 9),
                     textcoords='offset points',
                     fontsize=12,
                     fontweight='bold')

plt.title('방법론별 공구 이름 정제 정확도 비교', fontsize=16, fontweight='bold')
plt.ylabel('정확도 (Accuracy)', fontsize=14)
plt.xlabel('방법론', fontsize=14)
plt.xticks(rotation=45, ha='right') # 모델 이름이 길 경우 회전하여 겹침 방지
plt.ylim(0, 1.05) 

# 시각화 결과 보여주기
plt.tight_layout() # 그래프 요소가 잘리지 않도록 레이아웃 자동 조정

plt.savefig('./Data/Pigure/LLM_Accuracy/'+'Accuracy_Camprison_hue2')
plt.show()
print("\n--- 모든 평가 완료 ---")
# Out:
# --- 모든 평가 완료 ---

# %% [markdown]
# # 데이터 유형별 살펴보기

# %%
df_ca
# Out:
#      Original_Name Correct_Name Brand Power_Source Specification  \
# 0         180mm 샌더           샌더   NaN          NaN         180mm
# 1          LED 손전등          손전등   NaN          NaN           LED
# 2        경랑몽키(8인치)        몽키스패너   NaN          NaN        경량 8인치
# 3            고압세척기        고압세척기   NaN          NaN           NaN
# 4          바이스플라이어      바이스플라이어   NaN          NaN           NaN
# ...            ...          ...   ...          ...           ...
# 3347       휴대용에어펌프         에어펌프   NaN           무선           NaN
# 3348        휴대용유모차          유모차   NaN          NaN           NaN
# 3349       휴대용육각렌치         육각렌치   NaN          NaN           접이식
# 3350            흙손          미장칼   NaN          NaN           NaN
# 3351       힐티기리6mm         드릴비트    힐티          NaN           6mm
#
#      SubCategories Categories Dirtydata_Category Dirtydata_Subtype  \
# 0            샌더/대패       전동공구              정보중복형              속성기입
# 1          기타 일반공구       일반공구              정보중복형             동력원명시
# 2        몽키/렌치/스패너       일반공구              표준위배형               오탈자
# 3             기타공구       기타공구              정보중복형             동력원명시
# 4       니퍼/펜치/플라이어       일반공구                NaN               NaN
# ...            ...        ...                ...               ...
# 3347       기타 생활용품       생활용품              정보중복형             동력원명시
# 3348       기타 생활용품       생활용품                NaN               NaN
# 3349     몽키/렌치/스패너       일반공구                NaN               NaN
# 3350        도장/페인트       일반공구                NaN               NaN
# 3351            비트       전동공구              정보중복형             브랜드혼입
#
#                                             근거 (보고서 패턴)
# 0                      규격('180mm')이 Original_Name에 포함됨.
# 1     손전등'은 암묵적으로 동력원(충전)을 가짐에도 이름에 동력원이 없음이 플래그됨 (암...
# 2                                       경랑'은 '경량'의 오탈자.
# 3     동력원 언급이 없지만 Power_Source가 올바르게 분류됨 (암묵적 규칙 충돌의...
# 4            분류표에 명시된 더티 데이터 유형에 해당하지 않는 깨끗한 제품명으로 판단됨.
# ...                                                 ...
# 3347                                       동력원 '에어' 포함.
# 3348                                            공구가 아님.
# 3349                            명확한 더티 데이터 유형에 해당하지 않음.
# 3350                            명확한 더티 데이터 유형에 해당하지 않음.
# 3351                                       브랜드 '힐티' 포함.
#
# [3352 rows x 10 columns]

# %%
df_eval_cf = df_eval.copy()
df_eval_cf[['Dirtydata_Category','Dirtydata_Subtype','근거 (보고서 패턴)']] = df_ca[['Dirtydata_Category','Dirtydata_Subtype','근거 (보고서 패턴)']]

# %%
df_eval_cf.to_csv(file_path+'New_Evaluation_Dataset.csv',index=False, encoding='utf-8-sig')
df_eval_cf.to_excel(file_path+'New_Evaluation_Dataset.xlsx',index=False)
